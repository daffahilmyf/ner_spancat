# %%
import matplotlib.pyplot as plt
import json
import jsonlines
import random

# %%
def filter_objects_by_text(arr1, arr2):
    text_set2 = set(obj2["text"] for obj2 in arr2)
    text_set1 = set(obj1["text"] for obj1 in arr1)

    text_filter = text_set1 & text_set2

    unique_texts1 = set()
    arr1_filtered = []
    for obj1 in arr1:
        if obj1["text"] not in unique_texts1 and obj1["text"] in text_filter:
            arr1_filtered.append(obj1)
            unique_texts1.add(obj1["text"])
    return arr1_filtered

def count_labels(datasets, labels):
    count = {label: 0 for label in labels}
    label_counts = {label: label for label in labels}
    for dataset in datasets:
        if "spans" in dataset:
            for span in dataset["spans"]:
                label = span.get("label")
                if label in count.keys():
                    count[label_counts[label]] += 1
    return count

def delete_objects_with_label(input_array, desired_delete_numbers, label_to_delete):
    # Use a list comprehension to filter the objects with the specified label
    # Find all elements with the specified label
    matching_elements = [element for element in input_array if element["accept"][0] == label_to_delete]
    
    # Determine how many elements to delete
    delete_count = min(len(matching_elements), desired_delete_numbers)
    
    # Delete random elements from the list
    deleted_elements = random.sample(matching_elements, delete_count)
    new_array = [element for element in input_array if element not in deleted_elements]
    
    # Return the new array and the deleted elements
    return (new_array, deleted_elements)

def save_to_jsonl(datasets, filepath):
    with open(f'{filepath}', 'w') as f1:
        for obj in datasets:
            json_str = json.dumps(obj)
            f1.write(json_str + '\n')

# %%
filepath = "./assets/prodigy"


dataset1 = []
dataset2 = []
# Load the two datasets
with jsonlines.open(f'{filepath}/annotator-1/spacy-format/final.jsonl', 'r') as f1, jsonlines.open(f'{filepath}/annotator-2/spacy-format/final.jsonl', 'r') as f2:


    for data in f1:
        if(len(data['accept'])>0):
            dataset1.append(data)

    for data in f2:
        if(len(data['accept'])>0):
            dataset2.append(data)

dataset1_normalize = filter_objects_by_text(dataset1, dataset2)
dataset2_normalize = filter_objects_by_text(dataset2, dataset1)

# %%
dataset1_balanced, filter_delete = delete_objects_with_label(dataset1_normalize, 1600, "POSTCONDITION")
delete_ids = [obj["text"] for obj in filter_delete]
dataset2_balanced = [obj for obj in dataset2_normalize if obj["text"] not in delete_ids]

# %%
labels = ["PRECONDITION", "POSTCONDITION", "ACTOR", "QUALITY"]
data = {
    "annotator_1": count_labels(dataset1_balanced, labels),
    "annotator_2": count_labels(dataset2_balanced, labels)
}

# %%
data
# Out:
# {'annotator_1': {'PRECONDITION': 475,
#   'POSTCONDITION': 536,
#   'ACTOR': 853,
#   'QUALITY': 783},
#  'annotator_2': {'PRECONDITION': 410,
#   'POSTCONDITION': 583,
#   'ACTOR': 479,
#   'QUALITY': 3}}

# %%
import random
# Randomly shuffle the data
random.shuffle(dataset1_normalize)

# Split the data into training and testing sets
split_idx = int(len(dataset1_normalize) * 0.8)
train_data = dataset1_normalize[:split_idx]
test_data = dataset1_normalize[split_idx:]

# %%
save_to_jsonl(dataset1_balanced, "./assets/prodigy/annotator-1/spacy-format/normalize-balance.jsonl")
save_to_jsonl(dataset2_balanced, "./assets/prodigy/annotator-2/spacy-format/normalize-balance.jsonl")

# %%
# with open(f'{filepath}/annotator-1/normalize.jsonl', 'w') as f1, open(f'{filepath}/annotator-2/normalize.jsonl', 'w') as f2:
#     for obj in dataset1_balanced:
#         json_str = json.dumps(obj)
#         f1.write(json_str + '\n')

#     for obj in dataset2_balanced:
#         json_str = json.dumps(obj)
#         f2.write(json_str + '\n')

# %%
for dataset in dataset1:
    if('spans' in dataset.keys()):
        dataset['spans'] = [span for span in dataset['spans'] if span['label'] in ["POSTCONDITION", "PRECONDITION"]]

# %%
save_to_jsonl(dataset2_normalize, "./assets/prodigy/annotator-2/spacy-format/normalize.jsonl")

# %%
import spacy
from spacy import displacy
from spacy.tokens import Span

# %%
data_test = [
    "The nurse shall be able to login to the store",
]

# %%
data = "./corpus/annotator-1/pure-normalize/spacy-spancat/overlapping/dev.spacy"

# %%
model = spacy.load("./training/test/model-best")
for item in range(len(data_test)):
    doc = model(data_test[item])
    spans = [(span.text, span.label_) for span in doc.spans["sc"]]
    displacy.render(doc, style="span")
# Out:
# <span class="tex2jax_ignore"><div class="spans" style="line-height: 2.5; direction: ltr">
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     The
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         POSTCONDITION
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 77px;">
#     nurse
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
# <span style="background: #ddd; top: 57px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 57px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ACTOR
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     shall
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     be
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     able
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     to
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     login
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     to
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     the
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     store
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# </div></span>

# %%
from prodigy.components.db import connect
db = connect()

db.datasets
# Out:
# ['annotator_1_normalize_test',
#  'annotator_1_normalize_train',
#  'annotator_2_normalize']

# %%
for data in db.datasets:
    db.drop_dataset(data)
db.datasets
# Out:
# []

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
data = nlp("Within the shunting group, it shall be possible for only one member of the group to transmit the link assurance signal at any time.")

token = [token for token in data]
len(token)
# Out:
# 26

# %%
len("Within the shunting group, it shall be possible for only one member of the group to transmit the link assurance signal at any time.".split())

# %%
#  Convert to new dataset

from prodigy.components.db import connect
import spacy
from spacy.tokenizer import Tokenizer

# Flow: Final -> normalize -> balance

import spacy

nlp = spacy.load("en_core_web_sm")


db = connect()
prodigy_annotations = db.get_dataset("annotator_1_final")
examples = ((eg["text"], eg) for eg in prodigy_annotations)
nlp = spacy.blank("en")
index = 1
IOB_format2 = []

for doc, eg in nlp.pipe(examples, as_tuples=True):
    try:
        other_doc = doc
        if "spans" in eg.keys():
            # Set entities for the "ACTOR" and "QUALITY" labels in the "other" doc
            other_doc.ents = [other_doc.char_span(s["start"], s["end"], s["label"]) for s in eg["spans"] if s["label"] in ["ACTOR", "QUALITY"]]
            # Generate IOB tags for the "condition" and "other" docs separately
            other_iob_tags = [f"{t.ent_iob_}-{t.ent_type_}" if t.ent_iob_ else "O" for t in other_doc]

        data = nlp(doc.text)

        for item in range(len(data)):
                IOB_format2.append((other_iob_tags[item]))


    except:
        index = index + 1
    IOB_format2.append((""))


prodigy_annotations = db.get_dataset("annotator_1_final")
examples = ((eg["text"], eg) for eg in prodigy_annotations)
nlp = spacy.blank("en")
index = 1
IOB_format1 = []

for doc, eg in nlp.pipe(examples, as_tuples=True):
    try:
        condition_doc = doc
        other_doc = doc
        if "spans" in eg.keys():
            # Set entities for the "POSTCONDITION" and "PRECONDITION" labels in the "condition" doc
            condition_doc.ents = [condition_doc.char_span(s["start"], s["end"], s["label"]) for s in eg["spans"] if s["label"] in ["POSTCONDITION", "PRECONDITION"]]
            # Generate IOB tags for the "condition" and "other" docs separately
            condition_iob_tags = [f"{t.ent_iob_}-{t.ent_type_}" if t.ent_iob_ else "O" for t in condition_doc]

            data = nlp(doc.text)

            for item in range(len(data)):
                IOB_format1.append((data[item], condition_iob_tags[item]))
    except:
        index = index + 1

    IOB_format1.append(("","","",))

# %%
IOB_format1
# Out:
# [(Within, 'B-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (shunting, 'I-PRECONDITION'),
#  (group, 'I-PRECONDITION'),
#  (,, 'O-'),
#  (it, 'B-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (possible, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (only, 'I-POSTCONDITION'),
#  (one, 'I-POSTCONDITION'),
#  (member, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (group, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (transmit, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (link, 'I-POSTCONDITION'),
#  (assurance, 'I-POSTCONDITION'),
#  (signal, 'I-POSTCONDITION'),
#  (at, 'I-POSTCONDITION'),
#  (any, 'I-POSTCONDITION'),
#  (time, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (When, 'B-PRECONDITION'),
#  (applicable, 'I-PRECONDITION'),
#  (a, 'I-PRECONDITION'),
#  (Security, 'I-PRECONDITION'),
#  (Domain, 'I-PRECONDITION'),
#  (shall, 'B-POSTCONDITION'),
#  (Request, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (OPEN, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (load, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (install, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (extradite, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (delete, 'I-POSTCONDITION'),
#  (card, 'I-POSTCONDITION'),
#  (content, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (Bootstrap, 'I-POSTCONDITION'),
#  (Monitor, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (DPU, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (BOOT, 'I-POSTCONDITION'),
#  (CSC, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (output, 'I-POSTCONDITION'),
#  (an, 'I-POSTCONDITION'),
#  (error, 'I-POSTCONDITION'),
#  (message, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (RS-232, 'I-POSTCONDITION'),
#  (interface, 'I-POSTCONDITION'),
#  (if, 'B-PRECONDITION'),
#  (an, 'I-PRECONDITION'),
#  (incorrect, 'I-PRECONDITION'),
#  (number, 'I-PRECONDITION'),
#  (of, 'I-PRECONDITION'),
#  (command, 'I-PRECONDITION'),
#  (arguments, 'I-PRECONDITION'),
#  (are, 'I-PRECONDITION'),
#  (entered, 'I-PRECONDITION'),
#  (., 'I-PRECONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (DPU, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (SCUI, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (capable, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (preparing, 'I-POSTCONDITION'),
#  (one, 'I-POSTCONDITION'),
#  (STPDU, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (delivery, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (SCU, 'I-POSTCONDITION'),
#  (every, 'I-POSTCONDITION'),
#  (M, 'I-POSTCONDITION'),
#  (milliseconds, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (or, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (indicate, 'I-POSTCONDITION'),
#  (a, 'I-POSTCONDITION'),
#  (No, 'I-POSTCONDITION'),
#  (Data, 'I-POSTCONDITION'),
#  (condition, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (SCU, 'I-POSTCONDITION'),
#  (by, 'I-POSTCONDITION'),
#  (maintaining, 'I-POSTCONDITION'),
#  (an, 'I-POSTCONDITION'),
#  (un, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (incremented, 'I-POSTCONDITION'),
#  (ST_PDU, 'I-POSTCONDITION'),
#  (Transfer, 'I-POSTCONDITION'),
#  (Request, 'I-POSTCONDITION'),
#  (Counter, 'I-POSTCONDITION'),
#  (field, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (Scheme, 'B-POSTCONDITION'),
#  (providers, 'I-POSTCONDITION'),
#  (must, 'I-POSTCONDITION'),
#  (assign, 'I-POSTCONDITION'),
#  (unique, 'I-POSTCONDITION'),
#  (identifying, 'I-POSTCONDITION'),
#  (numbers, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (merchant, 'I-POSTCONDITION'),
#  (acquirers, 'I-POSTCONDITION'),
#  (who, 'I-POSTCONDITION'),
#  (provide, 'I-POSTCONDITION'),
#  (PSAMs, 'I-POSTCONDITION'),
#  ('', '', ''),
#  (If, 'B-PRECONDITION'),
#  (automatic, 'I-PRECONDITION'),
#  (network, 'I-PRECONDITION'),
#  (selection, 'I-PRECONDITION'),
#  (is, 'I-PRECONDITION'),
#  (implemented, 'I-PRECONDITION'),
#  (,, 'I-PRECONDITION'),
#  (it, 'B-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (possible, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (driver, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (activate, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (deactivate, 'I-POSTCONDITION'),
#  (automatic, 'I-POSTCONDITION'),
#  (network, 'I-POSTCONDITION'),
#  (selection, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (system, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (operate, 'I-POSTCONDITION'),
#  (within, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (Windows, 'I-POSTCONDITION'),
#  (XP, 'I-POSTCONDITION'),
#  (Professional, 'I-POSTCONDITION'),
#  (operating, 'I-POSTCONDITION'),
#  (system, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (A, 'B-POSTCONDITION'),
#  (VCD, 'I-POSTCONDITION'),
#  (system, 'I-POSTCONDITION'),
#  (MUST, 'I-POSTCONDITION'),
#  (provide, 'I-POSTCONDITION'),
#  (a, 'I-POSTCONDITION'),
#  (user, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (interface, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (economic, 'I-POSTCONDITION'),
#  (operator, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (uploading, 'I-POSTCONDITION'),
#  (an, 'I-POSTCONDITION'),
#  (existing, 'I-POSTCONDITION'),
#  (VCD, 'I-POSTCONDITION'),
#  (package, 'I-POSTCONDITION'),
#  ('', '', ''),
#  (In, 'B-PRECONDITION'),
#  (order, 'I-PRECONDITION'),
#  (to, 'I-PRECONDITION'),
#  (fulfil, 'I-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (requirements, 'I-PRECONDITION'),
#  (of, 'I-PRECONDITION'),
#  (some, 'I-PRECONDITION'),
#  (railways, 'I-PRECONDITION'),
#  (,, 'O-'),
#  (it, 'B-POSTCONDITION'),
#  (should, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (possible, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (provide, 'I-POSTCONDITION'),
#  (an, 'I-POSTCONDITION'),
#  (alternative, 'I-POSTCONDITION'),
#  (means, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (link, 'I-POSTCONDITION'),
#  (assurance, 'I-POSTCONDITION'),
#  (indication, 'I-POSTCONDITION'),
#  (., 'O-'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (radio, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (support, 'I-POSTCONDITION'),
#  (at, 'I-POSTCONDITION'),
#  (least, 'I-POSTCONDITION'),
#  (ten, 'I-POSTCONDITION'),
#  (different, 'I-POSTCONDITION'),
#  (languages, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (If, 'B-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (call, 'I-PRECONDITION'),
#  (fails, 'I-PRECONDITION'),
#  (in, 'I-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (lead, 'I-PRECONDITION'),
#  (traction, 'I-PRECONDITION'),
#  (vehicle, 'I-PRECONDITION'),
#  (,, 'O-'),
#  (the, 'B-POSTCONDITION'),
#  (lead, 'I-POSTCONDITION'),
#  (driver, 'I-POSTCONDITION'),
#  (will, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (responsible, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (re-, 'I-POSTCONDITION'),
#  (establishing, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (call, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  (If, 'B-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (call, 'I-PRECONDITION'),
#  (fails, 'I-PRECONDITION'),
#  (to, 'I-PRECONDITION'),
#  (any, 'I-PRECONDITION'),
#  (other, 'I-PRECONDITION'),
#  (cab, 'I-PRECONDITION'),
#  (,, 'I-PRECONDITION'),
#  (the, 'B-POSTCONDITION'),
#  (driver, 'I-POSTCONDITION'),
#  (in, 'I-POSTCONDITION'),
#  (that, 'I-POSTCONDITION'),
#  (cab, 'I-POSTCONDITION'),
#  (will, 'I-POSTCONDITION'),
#  (call, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (lead, 'I-POSTCONDITION'),
#  (cab, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (request, 'I-POSTCONDITION'),
#  (re, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (establishment, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (call, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'O-'),
#  (CNG, 'O-'),
#  (shall, 'O-'),
#  (classify, 'O-'),
#  (packets, 'O-'),
#  (entering, 'O-'),
#  (the, 'O-'),
#  (CPN, 'O-'),
#  (through, 'O-'),
#  (its, 'O-'),
#  (WAN, 'O-'),
#  (interface, 'B-POSTCONDITION'),
#  ((, 'I-POSTCONDITION'),
#  (downstream, 'I-POSTCONDITION'),
#  (direction, 'I-POSTCONDITION'),
#  (), 'I-POSTCONDITION'),
#  (according, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (a, 'I-POSTCONDITION'),
#  (number, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (predefined, 'I-POSTCONDITION'),
#  (priorities, 'I-POSTCONDITION'),
#  (., 'O-'),
#  (Classification, 'B-POSTCONDITION'),
#  (can, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (done, 'I-POSTCONDITION'),
#  (on, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (basis, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (different, 'I-POSTCONDITION'),
#  (layer, 'I-POSTCONDITION'),
#  (2, 'I-POSTCONDITION'),
#  (and/or, 'I-POSTCONDITION'),
#  (layer, 'I-POSTCONDITION'),
#  (3, 'I-POSTCONDITION'),
#  (parameters, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (DPU, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (ADC, 'I-POSTCONDITION'),
#  (CSC, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (address, 'I-POSTCONDITION'),
#  (hardware, 'I-POSTCONDITION'),
#  (modules, 'I-POSTCONDITION'),
#  (as, 'I-POSTCONDITION'),
#  (defined, 'I-POSTCONDITION'),
#  (in, 'I-POSTCONDITION'),
#  (document, 'I-POSTCONDITION'),
#  (1400, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (Company, 'I-POSTCONDITION'),
#  (X, 'I-POSTCONDITION'),
#  (Specification, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (Company, 'I-POSTCONDITION'),
#  (X, 'I-POSTCONDITION'),
#  (Communication, 'I-POSTCONDITION'),
#  (/, 'I-POSTCONDITION'),
#  (Memory, 'I-POSTCONDITION'),
#  (Module, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-PRECONDITION'),
#  (card, 'I-PRECONDITION'),
#  (should, 'I-PRECONDITION'),
#  (use, 'I-PRECONDITION'),
#  (a, 'I-PRECONDITION'),
#  (unique, 'I-PRECONDITION'),
#  (diversified, 'I-PRECONDITION'),
#  (secret, 'I-PRECONDITION'),
#  (key, 'I-PRECONDITION'),
#  (,, 'I-PRECONDITION'),
#  (personalized, 'I-PRECONDITION'),
#  (into, 'I-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (card, 'I-PRECONDITION'),
#  (,, 'O-'),
#  (to, 'B-POSTCONDITION'),
#  (generate, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (authenticate, 'I-POSTCONDITION'),
#  (transaction, 'I-POSTCONDITION'),
#  (signatures, 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (PSAM, 'I-POSTCONDITION'),
#  (must, 'I-POSTCONDITION'),
#  (create, 'I-POSTCONDITION'),
#  (a, 'I-POSTCONDITION'),
#  (MAC, 'I-POSTCONDITION'),
#  (on, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (updated, 'I-POSTCONDITION'),
#  (aggregation, 'I-POSTCONDITION'),
#  (record, 'I-POSTCONDITION'),
#  (., 'O-'),
#  (Aggregation, 'B-POSTCONDITION'),
#  (records, 'I-POSTCONDITION'),
#  (by, 'I-POSTCONDITION'),
#  (card, 'I-POSTCONDITION'),
#  (issuer, 'I-POSTCONDITION'),
#  (must, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (stored, 'I-POSTCONDITION'),
#  (in, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (PSAM, 'I-POSTCONDITION'),
#  (., 'O-'),
#  (They, 'B-POSTCONDITION'),
#  (may, 'I-POSTCONDITION'),
#  (also, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (stored, 'I-POSTCONDITION'),
#  (in, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (POS, 'I-POSTCONDITION'),
#  (device, 'I-POSTCONDITION'),
#  (as, 'I-POSTCONDITION'),
#  (well, 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (Development, 'I-POSTCONDITION'),
#  (Team, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (required, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (adjust, 'I-POSTCONDITION'),
#  (existing, 'I-POSTCONDITION'),
#  (source, 'I-POSTCONDITION'),
#  (code, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (use, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (externallog, 'I-POSTCONDITION'),
#  (file, 'I-POSTCONDITION'),
#  (only, 'I-POSTCONDITION'),
#  (if, 'B-PRECONDITION'),
#  (that, 'I-PRECONDITION'),
#  (source, 'I-PRECONDITION'),
#  (code, 'I-PRECONDITION'),
#  (must, 'I-PRECONDITION'),
#  (be, 'I-PRECONDITION'),
#  (modified, 'I-PRECONDITION'),
#  (to, 'I-PRECONDITION'),
#  (implement, 'I-PRECONDITION'),
#  (another, 'I-PRECONDITION'),
#  (requirement, 'I-PRECONDITION'),
#  (., 'I-PRECONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (Disputes, 'I-POSTCONDITION'),
#  (application, 'I-POSTCONDITION'),
#  (must, 'I-POSTCONDITION'),
#  (conform, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (legal, 'I-POSTCONDITION'),
#  (requirements, 'I-POSTCONDITION'),
#  (as, 'I-POSTCONDITION'),
#  (specified, 'I-POSTCONDITION'),
#  (by, 'I-POSTCONDITION'),
#  (Regulation, 'I-POSTCONDITION'),
#  (E, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (Regulation, 'I-POSTCONDITION'),
#  (Z, 'I-POSTCONDITION'),
#  (that, 'I-POSTCONDITION'),
#  (govern, 'I-POSTCONDITION'),
#  (credit, 'I-POSTCONDITION'),
#  (card, 'I-POSTCONDITION'),
#  (disputes, 'I-POSTCONDITION'),
#  (processing, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (In, 'B-PRECONDITION'),
#  (Image, 'I-PRECONDITION'),
#  (Mode, 'I-PRECONDITION'),
#  (,, 'O-'),
#  (the, 'B-POSTCONDITION'),
#  (DPU, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (DPA, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (capable, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (binning, 'I-POSTCONDITION'),
#  (images, 'I-POSTCONDITION'),
#  (at, 'I-POSTCONDITION'),
#  (different, 'I-POSTCONDITION'),
#  (levels, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (Policies, 'B-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (procedures, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (communicating, 'I-POSTCONDITION'),
#  (information, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (appropriate, 'I-POSTCONDITION'),
#  (stakeholders, 'I-POSTCONDITION'),
#  ((, 'I-POSTCONDITION'),
#  (e.g., 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (state, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (federal, 'I-POSTCONDITION'),
#  (emergency, 'I-POSTCONDITION'),
#  (management, 'I-POSTCONDITION'),
#  (organizations, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (FEMA, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (hazmat, 'I-POSTCONDITION'),
#  (teams, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (public, 'I-POSTCONDITION'),
#  (works, 'I-POSTCONDITION'),
#  (facilities, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (intelligence, 'I-POSTCONDITION'),
#  (organizations, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (media, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (public, 'I-POSTCONDITION'),
#  (), 'I-POSTCONDITION'),
#  (should, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (clearly, 'I-POSTCONDITION'),
#  (defined, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (MMI, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (suitable, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (use, 'I-POSTCONDITION'),
#  (by, 'I-POSTCONDITION'),
#  (day, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (night, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (DPU, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (ICUI, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (provide, 'I-POSTCONDITION'),
#  (ICUI_HK, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (DPU, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (CCM, 'I-POSTCONDITION'),
#  (on, 'I-POSTCONDITION'),
#  (request, 'I-POSTCONDITION'),
#  (., 'O-'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (DPU, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (SCUI, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (provide, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (capability, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (data, 'I-POSTCONDITION'),
#  (producing, 'I-POSTCONDITION'),
#  (applications, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (specify, 'I-POSTCONDITION'),
#  (whether, 'I-POSTCONDITION'),
#  (or, 'I-POSTCONDITION'),
#  (not, 'I-POSTCONDITION'),
#  (queued, 'I-POSTCONDITION'),
#  (data, 'I-POSTCONDITION'),
#  (may, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (segmented, 'I-POSTCONDITION'),
#  (., 'O-'),
#  ('', '', ''),
#  (In, 'B-PRECONDITION'),
#  (case, 'I-PRECONDITION'),
#  (of, 'I-PRECONDITION'),
#  (multicast, 'I-PRECONDITION'),
#  (streams, 'I-PRECONDITION'),
#  (the, 'B-POSTCONDITION'),
#  (CNG, 'I-POSTCONDITION'),
#  (should, 'I-POSTCONDITION'),
#  (support, 'I-POSTCONDITION'),
#  (proxy, 'I-POSTCONDITION'),
#  (functionalities, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (optimize, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (management, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (information, 'I-POSTCONDITION'),
#  (related, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (signalling, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (ETCS, 'I-POSTCONDITION'),
#  (trainborne, 'I-POSTCONDITION'),
#  (equipment, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (indicate, 'I-POSTCONDITION'),
#  (on, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (DMI, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (information, 'I-POSTCONDITION'),
#  (regarding, 'I-POSTCONDITION'),
#  (pantograph, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (power, 'I-POSTCONDITION'),
#  (supply, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (Contain, 'B-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (details, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (a, 'I-POSTCONDITION'),
#  (transaction, 'I-POSTCONDITION'),
#  (between, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (initialize, 'I-POSTCONDITION'),
#  (command, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (that, 'I-POSTCONDITION'),
#  (transaction, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (initialize, 'I-POSTCONDITION'),
#  (command, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (next, 'I-POSTCONDITION'),
#  (transaction, 'I-POSTCONDITION'),
#  ('', '', ''),
#  (Contraindication, 'B-POSTCONDITION'),
#  (information, 'I-POSTCONDITION'),
#  (should, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (collected, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (indicate, 'I-POSTCONDITION'),
#  (why, 'I-POSTCONDITION'),
#  (vaccinations, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (treatments, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (or, 'I-POSTCONDITION'),
#  (antidotes, 'I-POSTCONDITION'),
#  (may, 'I-POSTCONDITION'),
#  (not, 'I-POSTCONDITION'),
#  (have, 'I-POSTCONDITION'),
#  (been, 'I-POSTCONDITION'),
#  (administered, 'I-POSTCONDITION'),
#  (or, 'I-POSTCONDITION'),
#  (why, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (patient, 'I-POSTCONDITION'),
#  (may, 'I-POSTCONDITION'),
#  (not, 'I-POSTCONDITION'),
#  (have, 'I-POSTCONDITION'),
#  (complied, 'I-POSTCONDITION'),
#  (with, 'I-POSTCONDITION'),
#  (prescribed, 'I-POSTCONDITION'),
#  (interventions, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (DPU, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (EDAC, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (record, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (current, 'I-POSTCONDITION'),
#  (contents, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (EDAC_HK, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (EEPROM, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (force, 'I-POSTCONDITION'),
#  (a, 'I-POSTCONDITION'),
#  (DPU, 'I-POSTCONDITION'),
#  (watchdog, 'I-POSTCONDITION'),
#  (in, 'B-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (event, 'I-PRECONDITION'),
#  (an, 'I-PRECONDITION'),
#  (MBE, 'I-PRECONDITION'),
#  (in, 'I-PRECONDITION'),
#  (DRAM, 'I-PRECONDITION'),
#  (is, 'I-PRECONDITION'),
#  (detected, 'I-PRECONDITION'),
#  (., 'I-PRECONDITION'),
#  ('', '', ''),
#  (Perform, 'B-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (calculation, 'I-PRECONDITION'),
#  (required, 'I-PRECONDITION'),
#  (to, 'I-PRECONDITION'),
#  (generate, 'I-PRECONDITION'),
#  (a, 'I-PRECONDITION'),
#  (signature, 'I-PRECONDITION'),
#  (using, 'I-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (PSAM, 'I-PRECONDITION'),
#  ('s, 'I-PRECONDITION'),
#  (private, 'I-PRECONDITION'),
#  (RSA, 'I-PRECONDITION'),
#  (key, 'I-PRECONDITION'),
#  (,, 'O-'),
#  (to, 'B-POSTCONDITION'),
#  (allow, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (CEP, 'I-POSTCONDITION'),
#  (card, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (validate, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (PSAM, 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (preferred, 'I-POSTCONDITION'),
#  (repair, 'I-POSTCONDITION'),
#  (facility, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (returned, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (user, 'I-POSTCONDITION'),
#  (., 'O-'),
#  ('', '', ''),
#  (The, 'B-PRECONDITION'),
#  (DPU, 'I-PRECONDITION'),
#  (-, 'I-PRECONDITION'),
#  (CCM, 'I-PRECONDITION'),
#  (shall, 'I-PRECONDITION'),
#  (use, 'I-PRECONDITION'),
#  (DPU, 'I-PRECONDITION'),
#  (-, 'I-PRECONDITION'),
#  (EEPRM, 'I-PRECONDITION'),
#  (to, 'B-POSTCONDITION'),
#  (access, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (EEPROM, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (user, 'I-POSTCONDITION'),
#  (should, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (able, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (personalize, 'I-POSTCONDITION'),
#  (bookmarks, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (UGC, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (terminal, 'I-POSTCONDITION'),
#  (must, 'I-POSTCONDITION'),
#  (secure, 'I-POSTCONDITION'),
#  (transactions, 'I-POSTCONDITION'),
#  (by, 'I-POSTCONDITION'),
#  (retaining, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (card, 'I-POSTCONDITION'),
#  ('s, 'I-POSTCONDITION'),
#  (symmetric, 'I-POSTCONDITION'),
#  (MACing, 'I-POSTCONDITION'),
#  (key, 'I-POSTCONDITION'),
#  (signature, 'I-POSTCONDITION'),
#  (as, 'I-POSTCONDITION'),
#  (part, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (transaction, 'I-POSTCONDITION'),
#  ('', '', ''),
#  (System, 'B-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (let, 'I-POSTCONDITION'),
#  (customers, 'I-POSTCONDITION'),
#  (cancel, 'I-POSTCONDITION'),
#  (their, 'I-POSTCONDITION'),
#  (account, 'I-POSTCONDITION'),
#  (process, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (take, 'I-POSTCONDITION'),
#  (no, 'I-POSTCONDITION'),
#  (longer, 'I-POSTCONDITION'),
#  (than, 'I-POSTCONDITION'),
#  (2, 'I-POSTCONDITION'),
#  (minutes, 'I-POSTCONDITION'),
#  (., 'O-'),
#  (Database, 'B-POSTCONDITION'),
#  (will, 'I-POSTCONDITION'),
#  (mark, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (account, 'I-POSTCONDITION'),
#  (as, 'I-POSTCONDITION'),
#  (inactive, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (user, 'I-POSTCONDITION'),
#  (will, 'I-POSTCONDITION'),
#  (not, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (able, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (log, 'I-POSTCONDITION'),
#  (into, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (website, 'I-POSTCONDITION'),
#  (., 'O-'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (load, 'I-POSTCONDITION'),
#  (device, 'I-POSTCONDITION'),
#  (which, 'I-POSTCONDITION'),
#  (supports, 'I-POSTCONDITION'),
#  (only, 'I-POSTCONDITION'),
#  (off, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (line, 'I-POSTCONDITION'),
#  (PIN, 'I-POSTCONDITION'),
#  (verification, 'I-POSTCONDITION'),
#  (must, 'I-POSTCONDITION'),
#  (support, 'I-POSTCONDITION'),
#  (both, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (off, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (line, 'I-POSTCONDITION'),
#  (PIN, 'I-POSTCONDITION'),
#  (encryption, 'I-POSTCONDITION'),
#  (method, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (off, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (line, 'I-POSTCONDITION'),
#  (PIN, 'I-POSTCONDITION'),
#  (plain, 'I-POSTCONDITION'),
#  (text, 'I-POSTCONDITION'),
#  (verification, 'I-POSTCONDITION'),
#  (method, 'I-POSTCONDITION'),
#  (as, 'I-POSTCONDITION'),
#  (defined, 'I-POSTCONDITION'),
#  (in, 'I-POSTCONDITION'),
#  (EMV, 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (weight, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (General, 'I-POSTCONDITION'),
#  (purpose, 'I-POSTCONDITION'),
#  (radio, 'I-POSTCONDITION'),
#  (including, 'I-POSTCONDITION'),
#  (battery, 'I-POSTCONDITION'),
#  (should, 'I-POSTCONDITION'),
#  (not, 'I-POSTCONDITION'),
#  (exceed, 'I-POSTCONDITION'),
#  (250, 'I-POSTCONDITION'),
#  (g., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (Track, 'B-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (train, 'I-POSTCONDITION'),
#  (transmission, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (provide, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (capability, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (send, 'I-POSTCONDITION'),
#  (different, 'I-POSTCONDITION'),
#  (speed, 'I-POSTCONDITION'),
#  (profiles, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (specific, 'I-POSTCONDITION'),
#  (train, 'I-POSTCONDITION'),
#  (categories, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (CNG, 'I-POSTCONDITION'),
#  (may, 'I-POSTCONDITION'),
#  (allow, 'I-POSTCONDITION'),
#  (secure, 'I-POSTCONDITION'),
#  (dynamic, 'I-POSTCONDITION'),
#  (firewall, 'I-POSTCONDITION'),
#  (opening, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (remote, 'I-POSTCONDITION'),
#  (access, 'I-POSTCONDITION'),
#  (devices, 'I-POSTCONDITION'),
#  (based, 'I-POSTCONDITION'),
#  (on, 'I-POSTCONDITION'),
#  (NGN, 'I-POSTCONDITION'),
#  (authentication, 'I-POSTCONDITION'),
#  (functions, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (Information, 'B-POSTCONDITION'),
#  (received, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (not, 'I-POSTCONDITION'),
#  (influence, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (traction, 'I-POSTCONDITION'),
#  (unit(s, 'I-POSTCONDITION'),
#  (), 'I-POSTCONDITION'),
#  (with, 'I-POSTCONDITION'),
#  (in, 'I-POSTCONDITION'),
#  (-, 'I-POSTCONDITION'),
#  (operative, 'I-POSTCONDITION'),
#  (cabs, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (The, 'B-POSTCONDITION'),
#  (product, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (provide, 'I-POSTCONDITION'),
#  (Monitoring, 'I-POSTCONDITION'),
#  (Services, 'I-POSTCONDITION'),
#  (., 'O-'),
#  (The, 'B-POSTCONDITION'),
#  (product, 'I-POSTCONDITION'),
#  (shall, 'I-POSTCONDITION'),
#  (be, 'I-POSTCONDITION'),
#  (easy, 'I-POSTCONDITION'),
#  (for, 'I-POSTCONDITION'),
#  (System, 'I-POSTCONDITION'),
#  (Administrators, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (DBAs, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (use, 'I-POSTCONDITION'),
#  (after, 'I-POSTCONDITION'),
#  (two, 'I-POSTCONDITION'),
#  (weeks, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (usage, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (For, 'B-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (CNG, 'I-POSTCONDITION'),
#  (management, 'I-POSTCONDITION'),
#  (it, 'I-POSTCONDITION'),
#  (is, 'I-POSTCONDITION'),
#  (recommended, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (use, 'I-POSTCONDITION'),
#  (a, 'I-POSTCONDITION'),
#  (single, 'I-POSTCONDITION'),
#  (protocol, 'I-POSTCONDITION'),
#  (,, 'I-POSTCONDITION'),
#  (so, 'I-POSTCONDITION'),
#  (as, 'I-POSTCONDITION'),
#  (to, 'I-POSTCONDITION'),
#  (minimize, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (complexity, 'I-POSTCONDITION'),
#  (and, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (cost, 'I-POSTCONDITION'),
#  (of, 'I-POSTCONDITION'),
#  (the, 'I-POSTCONDITION'),
#  (service, 'I-POSTCONDITION'),
#  (., 'I-POSTCONDITION'),
#  ('', '', ''),
#  (If, 'B-PRECONDITION'),
#  (errors, 'I-PRECONDITION'),
#  (in, 'I-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (card, 'I-PRECONDITION'),
#  (issuer, 'I-PRECONDITION'),
#  (MAC, 'I-PRECONDITION'),
#  (are, 'I-PRECONDITION'),
#  (discovered, 'I-PRECONDITION'),
#  (by, 'I-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (card, 'I-PRECONDITION'),
#  (issuer, 'I-PRECONDITION'),
#  (during, 'I-PRECONDITION'),
#  (its, 'I-PRECONDITION'),
#  (processing, 'I-PRECONDITION'),
#  (of, 'I-PRECONDITION'),
#  (the, 'I-PRECONDITION'),
#  (transactions, 'I-PRECONDITION'),
#  (,, 'O-'),
#  (a, 'B-POSTCONDITION'),
#  ...]

# %%
merge = [(x[0], x[1], y) for x, y in zip(IOB_format1, IOB_format2)]

# %%
import csv

filename = 'data.csv'

# Open the CSV file for writing
with open(filename, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=';')

    

    # Write the header row
    writer.writerow(['Word', 'Label1', 'Label2'])

    # Write the data rows
    for row in IOB_format1:
        row = [str(item).replace('O-', 'O') for item in row]
        # Remove the parentheses from the tuple
        row = [str(item).replace('(', '').replace(')', '') for item in row]
        writer.writerow(row)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer, WordNetLemmatizer

def preprocess_text(data, remove_stopwords=False, stem=False, lemma=False):
    # Download stopwords and initialize stemmer and lemmatizer
    nltk.download('stopwords')
    nltk.download('punkt')
    nltk.download('wordnet')
    stop_words = set(stopwords.words('english'))
    stemmer = SnowballStemmer('english')
    lemmatizer = WordNetLemmatizer()

    # Define a helper function to preprocess a single word
    def preprocess_word(word):
        if remove_stopwords and word in stop_words:
            return None
        if stem:
            word = stemmer.stem(word)
        if lemma:
            word = lemmatizer.lemmatize(word)
        return word

    # Preprocess each sentence in the data
    preprocessed_data = []
    for sentence in data:
        tokens = word_tokenize(sentence[0])
        preprocessed_tokens = []
        for token in tokens:
            preprocessed_word = preprocess_word(token.lower())
            if preprocessed_word is not None:
                preprocessed_tokens.append(preprocessed_word)
        preprocessed_data.append((preprocessed_tokens, sentence[1]))

    return preprocessed_data

# %%
# import nltk
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer, PorterStemmer

# # download necessary resources
# nltk.download('stopwords')
# nltk.download('wordnet')

# # define a function to preprocess text
# def preprocess(text):
#     # split the text into tokens
#     tokens = text.split()
    
#     # remove stopwords
#     stop_words = set(stopwords.words('english'))
#     filtered_tokens = [token for token in tokens if token.lower() not in stop_words]
    
#     # lemmatize the tokens
#     lemmatizer = WordNetLemmatizer()
#     lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    
#     # stem the tokens
#     stemmer = PorterStemmer()
#     stemmed_tokens = [stemmer.stem(token) for token in lemmatized_tokens]
    
#     # join the tokens back into text
#     preprocessed_text = ' '.join(stemmed_tokens)
    
#     return preprocessed_text

# # example IOB-formatted text
# iob_tags = ['B-ORG', 'I-ORG', 'O', 'B-PER', 'I-PER', 'O', 'O', 'B-LOC', 'I-LOC']

# # convert IOB-formatted text to plain text
# text = ' '.join([tag[2:] if tag.startswith('B-') or tag.startswith('S-') else '' for tag in iob_tags])

# # preprocess the text
# preprocessed_text = preprocess(text)

# # convert the preprocessed text back to IOB-formatted text
# preprocessed_iob_tags = []
# for tag in iob_tags:
#     if tag == 'O':
#         preprocessed_iob_tags.append('O')
#     else:
#         label = 'B-' + tag[2:] if tag.startswith('B-') else 'I-' + tag[2:]
#         preprocessed_iob_tags.append(label)

# print(preprocessed_iob_tags)

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "True"

# %%
# !python -m prodigy train --spancat final_ver_condition,eval:final_ver_condition --verbose

# %%
db.datasets
